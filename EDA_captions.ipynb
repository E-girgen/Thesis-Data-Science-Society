# %% [markdown]
# <a href="https://colab.research.google.com/github/E-girgen/Thesis-Data-Science-Society/blob/main/EDA_captions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd "/content/drive/MyDrive/Colab Notebooks"
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab Notebooks

# %%
data = pd.read_csv("captions_correct.txt", sep='\t')
 # Stel tab als scheidingsteken in

# %%
data['Category'].value_counts()
# Out:
# joy        340
# anger      198
# sadness    186
# neutral    135
# fear        96
# love        45
# Name: Category, dtype: int64

# %%
df= data.copy()

# %%
import matplotlib.pyplot as plt
category_counts = df['Category'].value_counts()

# Create a bar chart for the category counts
plt.figure(figsize=(10, 6))
category_counts.plot(kind='bar', color='lightblue')
plt.title('Frequency of Emotions Categories captions')
plt.xlabel('Emotion Category')
plt.ylabel('Counts')
plt.xticks(rotation=45)
plt.tight_layout()

# Show the plot
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df['Text_Length'] = df['ID'].apply(len)
# Kleurenpalet met blauwe neutrale kleuren
neutral_colors = ['#87CEEB', '#6CA6CD', '#4682B4', '#3D8B99', '#357083', '#2D6070']

df['Text_Length'] = df['ID'].apply(len)

# Definieer de gewenste volgorde voor de x-as
order = ['joy', 'anger', 'sadness', 'neutral', 'fear', 'love']

# Plot een boxplot met het blauwe neutrale kleurenpalet en de gewenste volgorde
plt.figure(figsize=(10, 6))
sns.boxplot(x='Category', y='Text_Length', data=df, order=order, palette=neutral_colors)
plt.title('Distribution of Text Lengths per Emotion Category Captions')
plt.show()

# %%
# Importeer pandas
import pandas as pd

# Maak een nieuwe DataFrame met de gewenste kolommen
nd = df[[ 'ID', 'Category']]

# Hernoem de kolom 'ID' naar 'Text' in de specifieke subset
nd.rename(columns={'ID': 'text'}, inplace=True)
# Out:
# <ipython-input-8-87aafa7094a6>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nd.rename(columns={'ID': 'text'}, inplace=True)

# %%
nd
nd.rename(columns={'text': 'Text'}, inplace=True)
# Out:
# <ipython-input-9-c36dac096920>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nd.rename(columns={'text': 'Text'}, inplace=True)

# %%
nd.to_csv("cleaned_captions_np.csv", index=False)

# %%
import nltk
nltk.download('punkt')
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from wordcloud import WordCloud
import matplotlib.pyplot as plt


# Bekijk de nieuwe DataFrame
print(nd.head())

# Neem de 'Text'-kolom uit de DataFrame
text_data = ' '.join(nd['Text'])

# Tokenizen en tekst naar kleine letters converteren
tokens = word_tokenize(text_data.lower())

# Verwijder stopwoorden en leestekens
stop_words = set(stopwords.words('dutch'))  # Nederlandse stopwoorden
tokens = [word for word in tokens if word.isalpha() and word not in stop_words]

# Woordfrequentie tellen
word_freq = {}
for word in tokens:
    if word not in word_freq:
        word_freq[word] = 1
    else:
        word_freq[word] += 1

# Wordcloud maken
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_freq)

plt.figure(figsize=(10, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
#                                                 Text Category
# 0  Kweenie of da gij al es goed hebt stilgestaan ...  neutral
# 1                                             Santé.      joy
# 2  Ja kvind wel spannend. Das zo ineens euh de vu...     fear
# 3  Als ik één dag werk in, in, in de horecazaak w...    anger
# 4  Een baas is een baas he, die moet je respecter...    anger

# %%
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Je hebt al een DataFrame 'nd'
# Hieronder wordt aangenomen dat 'nd' de gewenste DataFrame is

# Filter de DataFrame voor de 'fear'-categorie
fear_data = nd[nd['Category'] == 'fear']

# Neem de 'Text'-kolom uit de gefilterde DataFrame
text_data_fear = ' '.join(fear_data['Text'])

# Tokenizen en tekst naar kleine letters converteren
tokens = word_tokenize(text_data_fear.lower())

# Verwijder stopwoorden en leestekens
stop_words = set(stopwords.words('dutch'))  # Nederlandse stopwoorden
tokens = [word for word in tokens if word.isalpha() and word not in stop_words]

# Woordfrequentie tellen
word_freq = {}
for word in tokens:
    if word not in word_freq:
        word_freq[word] = 1
    else:
        word_freq[word] += 1

# Wordcloud maken
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_freq)

# Plot de woordwolk
plt.figure(figsize=(10, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Wordcloud for Category: Fear')
plt.show()

# %%
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Je hebt al een DataFrame 'nd'
# Hieronder wordt aangenomen dat 'nd' de gewenste DataFrame is

# Filter de DataFrame voor de 'fear'-categorie
fear_data = nd[nd['Category'] == 'sadness']

# Neem de 'Text'-kolom uit de gefilterde DataFrame
text_data_sadness = ' '.join(fear_data['Text'])

# Tokenizen en tekst naar kleine letters converteren
tokens = word_tokenize(text_data_fear.lower())

# Verwijder stopwoorden en leestekens
stop_words = set(stopwords.words('dutch'))  # Nederlandse stopwoorden
tokens = [word for word in tokens if word.isalpha() and word not in stop_words]

# Woordfrequentie tellen
word_freq = {}
for word in tokens:
    if word not in word_freq:
        word_freq[word] = 1
    else:
        word_freq[word] += 1

# Wordcloud maken
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_freq)

# Plot de woordwolk
plt.figure(figsize=(10, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Wordcloud for Category: sadness')
plt.show()

# %%
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Je hebt al een DataFrame 'nd'
# Hieronder wordt aangenomen dat 'nd' de gewenste DataFrame is

# Filter de DataFrame voor de 'fear'-categorie
fear_data = nd[nd['Category'] == 'anger']

# Neem de 'Text'-kolom uit de gefilterde DataFrame
text_data_anger = ' '.join(fear_data['Text'])

# Tokenizen en tekst naar kleine letters converteren
tokens = word_tokenize(text_data_fear.lower())

# Verwijder stopwoorden en leestekens
stop_words = set(stopwords.words('dutch'))  # Nederlandse stopwoorden
tokens = [word for word in tokens if word.isalpha() and word not in stop_words]

# Woordfrequentie tellen
word_freq = {}
for word in tokens:
    if word not in word_freq:
        word_freq[word] = 1
    else:
        word_freq[word] += 1

# Wordcloud maken
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_freq)

# Plot de woordwolk
plt.figure(figsize=(10, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Wordcloud for Category: anger')
plt.show()

# %%
sadness_data = nd[nd['Category'] == 'sadness']['Text']
fear_data = nd[nd['Category'] == 'fear']['Text']

# Tokenizen en tekst naar kleine letters converteren voor 'sadness'
tokens_sadness = set(word_tokenize(' '.join(sadness_data.str.lower())))

# Tokenizen en tekst naar kleine letters converteren voor 'fear'
tokens_fear = set(word_tokenize(' '.join(fear_data.str.lower())))

# Overeenkomstige woorden vinden
overlapping_words = tokens_sadness.intersection(tokens_fear)

print("Overeenkomstige woorden tussen sadness en fear:")
print(overlapping_words)
print(len(overlapping_words))
# Out:
# Overeenkomstige woorden tussen sadness en fear:
# ...

# %%
from matplotlib_venn import venn2
import matplotlib.pyplot as plt

# Aantal unieke woorden in 'sadness' en 'fear'
num_sadness_words = len(tokens_sadness)
num_fear_words = len(tokens_fear)

# Aantal overeenkomstige woorden
num_overlapping_words = len(overlapping_words)

# Creëer een Venn-diagram
venn_labels = {'100': num_sadness_words, '010': num_fear_words, '110': num_overlapping_words}
venn2(subsets=(num_sadness_words, num_fear_words, num_overlapping_words), set_labels=('Sadness', 'Fear'))

# Toon het aantal unieke en overlappende woorden
plt.text(0.5, 0.85, f'Sadness Unique Words: {num_sadness_words}', ha='center', va='center', fontsize=10, color='blue')
plt.text(0.5, 0.15, f'Fear Unique Words: {num_fear_words}', ha='center', va='center', fontsize=10, color='orange')
plt.text(0.5, 0.5, f'Overlappende Woorden: {num_overlapping_words}', ha='center', va='center', fontsize=12, color='green')

# Toon het diagram
plt.show()

# %%
sadness_data = nd[nd['Category'] == 'sadness']['Text']
anger_data = nd[nd['Category'] == 'anger']['Text']
fear_data= nd[nd['Category']== 'fear']['Text']


# Tokenizen en tekst naar kleine letters converteren voor 'sadness'
tokens_sadness = set(word_tokenize(' '.join(sadness_data.str.lower())))

# Tokenizen en tekst naar kleine letters converteren voor 'fear'
tokens_fear = set(word_tokenize(' '.join(fear_data.str.lower())))

# Overeenkomstige woorden vinden
overlapping_words = tokens_sadness.intersection(tokens_fear)

print("Overeenkomstige woorden tussen sadness en fear:")
print(overlapping_words)
print(len(overlapping_words))
# Out:
# Overeenkomstige woorden tussen sadness en fear:
# ...

# %%
from matplotlib_venn import venn2, venn3
import matplotlib.pyplot as plt

# Data voor elk sentiment
joy_data = nd[nd['Category'] == 'joy']['Text']
love_data = nd[nd['Category'] == 'love']['Text']
anger_data = nd[nd['Category'] == 'anger']['Text']
sadness_data = nd[nd['Category'] == 'sadness']['Text']
fear_data = nd[nd['Category'] == 'fear']['Text']

# Tokenizen en tekst naar kleine letters converteren voor elk sentiment
tokens_joy = set(word_tokenize(' '.join(joy_data.str.lower())))
tokens_love = set(word_tokenize(' '.join(love_data.str.lower())))
tokens_anger = set(word_tokenize(' '.join(anger_data.str.lower())))
tokens_sadness = set(word_tokenize(' '.join(sadness_data.str.lower())))
tokens_fear = set(word_tokenize(' '.join(fear_data.str.lower())))

# Overeenkomstige woorden vinden tussen Joy en Love
overlapping_words_joy_love = tokens_joy.intersection(tokens_love)

# Overeenkomstige woorden vinden tussen Anger, Sadness en Fear
overlapping_words_asf = tokens_anger.intersection(tokens_sadness, tokens_fear)

# Creëer Venn-diagram voor Joy en Love
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
venn2([tokens_joy, tokens_love], set_labels=('Joy', 'Love'))
plt.title('Joy vs Love')

# Creëer Venn-diagram voor Anger, Sadness en Fear
plt.subplot(1, 2, 2)
venn3([tokens_anger, tokens_sadness, tokens_fear], set_labels=('Anger', 'Sadness', 'Fear'))
plt.title('Anger vs Sadness vs Fear')

# Toon de overlappende woorden
print("Overeenkomstige woorden tussen Joy en Love:")
print(overlapping_words_joy_love)
print(len(overlapping_words_joy_love))

print("\nOvereenkomstige woorden tussen Anger, Sadness en Fear:")
print(overlapping_words_asf)
print(len(overlapping_words_asf))

# Toon de diagrammen
plt.tight_layout()
plt.show()
# Out:
# Overeenkomstige woorden tussen Joy en Love:
# ...

# %%
from matplotlib_venn import venn2
import matplotlib.pyplot as plt

# Data voor elk sentiment
neutral_data = nd[nd['Category'] == 'neutral']['Text']

# Tokenizen en tekst naar kleine letters converteren voor Neutral
tokens_neutral = set(word_tokenize(' '.join(neutral_data.str.lower())))

# Overeenkomstige woorden vinden tussen Neutral en andere emoties
overlap_counts = {}
for emotion, data in emotion_data.items():
    if emotion != 'Neutral':
        tokens_emotion = set(word_tokenize(' '.join(data.str.lower())))
        overlap_counts[emotion] = len(tokens_neutral.intersection(tokens_emotion))

# Bepaal welke emotie de meeste overlappende woorden heeft
most_overlap_emotion = max(overlap_counts, key=overlap_counts.get)
most_overlap_words = tokens_neutral.intersection(set(word_tokenize(' '.join(emotion_data[most_overlap_emotion].str.lower()))))

# Creëer een Venn-diagram tussen Neutral en de emotie met de meeste overlappende woorden
plt.figure(figsize=(8, 4))
venn2([tokens_neutral, set(word_tokenize(' '.join(emotion_data[most_overlap_emotion].str.lower())))], set_labels=('Neutral', most_overlap_emotion))
plt.title(f'Neutral vs {most_overlap_emotion}')

# Toon de overlappende woorden
print(f"Overeenkomstige woorden tussen Neutral en {most_overlap_emotion}:")
print(most_overlap_words)
print(len(most_overlap_words))

# Toon het diagram
plt.tight_layout()
plt.show()
# Out:
# Overeenkomstige woorden tussen Neutral en Joy:
# ...

# %%
from matplotlib_venn import venn3

# Sadness, fear, anger data selecteren
sadness_data = nd[nd['Category'] == 'sadness']['Text']
anger_data = nd[nd['Category'] == 'anger']['Text']
fear_data = nd[nd['Category'] == 'fear']['Text']

# Joy en love data selecteren
joy_data = nd[nd['Category'] == 'joy']['Text']
love_data = nd[nd['Category'] == 'love']['Text']

# Tokenizen en tekst naar kleine letters converteren voor 'sadness'
tokens_sadness = set(word_tokenize(' '.join(sadness_data.str.lower())))

# Tokenizen en tekst naar kleine letters converteren voor 'fear'
tokens_fear = set(word_tokenize(' '.join(fear_data.str.lower())))

# Tokenizen en tekst naar kleine letters converteren voor 'anger'
tokens_anger = set(word_tokenize(' '.join(anger_data.str.lower())))

# Tokenizen en tekst naar kleine letters converteren voor 'joy'
tokens_joy = set(word_tokenize(' '.join(joy_data.str.lower())))

# Tokenizen en tekst naar kleine letters converteren voor 'love'
tokens_love = set(word_tokenize(' '.join(love_data.str.lower())))

# Overeenkomstige woorden vinden tussen sadness, fear en anger
overlapping_words_sadness_fear_anger = tokens_sadness.intersection(tokens_fear, tokens_anger)

# Overeenkomstige woorden vinden tussen joy en love
overlapping_words_joy_love = tokens_joy.intersection(tokens_love)

# Overeenkomstige woorden tussen sadness, fear, anger en joy, love
overlapping_words_all = tokens_sadness.intersection(tokens_fear, tokens_anger, tokens_joy, tokens_love)

# Creëer een Venn-diagram voor sadness, fear, anger
venn3(subsets=(len(tokens_sadness), len(tokens_fear), len(overlapping_words_sadness_fear_anger),
               len(tokens_anger), len(overlapping_words_sadness_fear_anger),
               len(overlapping_words_sadness_fear_anger), len(overlapping_words_sadness_fear_anger)),
      set_labels=('Sadness', 'Fear', 'Anger'))

# Toon het diagram voor sadness, fear, anger
plt.title('Venn-diagram voor Sadness, Fear, Anger')
plt.show()

# Creëer een Venn-diagram voor joy, love
venn2(subsets=(len(tokens_joy), len(tokens_love), len(overlapping_words_joy_love)),
      set_labels=('Joy', 'Love'))

# Toon het diagram voor joy, love
plt.title('Venn-diagram voor Joy, Love')
plt.show()

# Creëer een Venn-diagram voor sadness, fear, anger, joy, love
venn3(subsets=(len(tokens_sadness), len(tokens_fear), len(overlapping_words_sadness_fear_anger),
               len(tokens_anger), len(overlapping_words_sadness_fear_anger),
               len(overlapping_words_sadness_fear_anger), len(overlapping_words_all)),
      set_labels=('Sadness', 'Fear', 'Anger', 'Joy, Love'))

# Toon het diagram voor sadness, fear, anger, joy, love
plt.title('Venn-diagram voor Sadness, Fear, Anger, Joy, Love')
plt.show()

# %%
# Joy en love data selecteren
joy_data = nd[nd['Category'] == 'joy']['Text']
love_data = nd[nd['Category'] == 'love']['Text']

# Tokenizen en tekst naar kleine letters converteren voor 'joy'
tokens_joy = set(word_tokenize(' '.join(joy_data.str.lower())))

# Tokenizen en tekst naar kleine letters converteren voor 'love'
tokens_love = set(word_tokenize(' '.join(love_data.str.lower())))

# Overeenkomstige woorden vinden tussen joy en love
overlapping_words_joy_love = tokens_joy.intersection(tokens_love)

# Toon de overlappende woorden tussen joy en love
print("\nOvereenkomstige woorden tussen joy en love:")
print(overlapping_words_joy_love)
print(len(overlapping_words_joy_love))

# %%
import nltk
nltk.download('stopwords')
# !pip install spacy
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ...

# %%
pip show spacy
# Out:
# Name: spacy
# Version: 3.6.1
# Summary: Industrial-strength Natural Language Processing (NLP) in Python
# Home-page: https://spacy.io
# Author: Explosion
# Author-email: contact@explosion.ai
# License: MIT
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: catalogue, cymem, jinja2, langcodes, murmurhash, numpy, packaging, pathy, preshed, pydantic, requests, setuptools, smart-open, spacy-legacy, spacy-loggers, srsly, thinc, tqdm, typer, wasabi
# Required-by: en-core-web-sm, fastai

# %%
python -m spacy download nl_core_news_sm

# %%
import spacy
import re

# Laad het Nederlandse model
nlp = spacy.load("nl_core_news_sm")

def clean_text(text):
    # Stap 1: Lowercasing
    text = text.lower()

    # Stap 2: Verwijderen van Speciale Tekens en Punctuatie
    text = re.sub(r'[^a-zA-Z0-9\sÀ-ÖØ-öø-ÿ-é]', '', text)


    doc = nlp(text)
    lemmatized_tokens = [token.lemma_ for token in doc]
    text = ' '.join(lemmatized_tokens)

    # Stap 5: Verwijderen van Overbodige Witruimte
    text = ' '.join(text.split())

    return text


# Voorbeeldgebruik:
originele_tekst = "Zeker, zeker. Dan ruïneert hij mijn leven gewoon en dan gaat het sowieso niet de goeie kant op. Hier is het rechtssysteem, vergeleken met Nederland, zit hier echt heel scheef in elkaar."

# %%
clean_text(originele_tekst)
# Out:
# 'zeker zeker dan ruïneren hij mijn leven gewoon en dan gaan het sowieso niet de goed kant op hier zijn het rechtssysteem vergelijken met Nederland zitten hier echt heel scheef in elkaar'

# %%
nd.iloc[3]
# Out:
# Text        Als ik één dag werk in, in, in de horecazaak w...
# Category                                                anger
# Name: 3, dtype: object

# %%
nd["Text"] = nd["Text"].apply(clean_text)
# Out:
# <ipython-input-14-25ea123d9e53>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nd["Text"] = nd["Text"].apply(clean_text)

# %%
nd["Text"]
# Out:
# 0      kweenie of da gij al es goed hebben stilgestaa...
# 1                                                  santé
# 2      ja kvind wel spannend das zo ineens euh de vuu...
# 3      als ik één dag werk in in in de horecazaak waa...
# 4      een baas zijn een baas he die moeten je respec...
#                              ...
# 995    jah ze werken hard eh als wij in België en die...
# 996     ah gij wa een ramp zijten gij allemaal hetzelfde
# 997    de sta lego van lord of the rings van star war...
# 998                     nu zijn we precies aant kamperen
# 999    ik hebben euh ooit es bja ik swing op elk fees...
# Name: Text, Length: 1000, dtype: object

# %%
cleaned_captions = nd.copy()

# Bekijk het resultaat
print(cleaned_captions)
# Out:
#                                                   Text Category
# 0    kweenie of da gij al es goed hebben stilgestaa...  neutral
# 1                                                santé      joy
# 2    ja kvind wel spannend das zo ineens euh de vuu...     fear
# 3    als ik één dag werk in in in de horecazaak waa...    anger
# 4    een baas zijn een baas he die moeten je respec...    anger
# ..                                                 ...      ...
# 995  jah ze werken hard eh als wij in België en die...  sadness
# 996   ah gij wa een ramp zijten gij allemaal hetzelfde    anger
# 997  de sta lego van lord of the rings van star war...  neutral
# 998                   nu zijn we precies aant kamperen      joy
# 999  ik hebben euh ooit es bja ik swing op elk fees...      joy
#
# [1000 rows x 2 columns]

# %%
# Opslaan naar een CSV-bestand
cleaned_captions.to_csv("cleaned_captions_pre.csv", index=False)

# %%
# !pip install unidecode

# %%
# Installeer spaCy
# !pip install -U spacy

# Download het Nederlandse taalmodel
# !python -m spacy download nl_core_news_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 44.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 6.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 5.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.6.1
#     Uninstalling spacy-3.6.1:
#       Successfully uninstalled spacy-3.6.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# en-core-web-sm 3.6.0 requires spacy<3.7.0,>=3.6.0, but you have spacy 3.7.2 which is incompatible.
# ...
# 2023-11-21 12:02:33.118716: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...
